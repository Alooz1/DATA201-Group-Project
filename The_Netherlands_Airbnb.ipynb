# %%
packages <- c("viridis", "readr", "jsonlite", "httr", "ggplot2", "dplyr", "stringr")
for(pkg in packages) {
  library(pkg, character.only = TRUE)
}
packages <- c("viridis", "readr", "jsonlite", "httr", "ggplot2", "dplyr", "stringr")
lapply(packages, library, character.only = TRUE)
# Out:
# Loading required package: viridisLite
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [[1]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[2]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[3]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[4]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[5]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[6]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"
#
# [[7]]
#  [1] "stringr"     "dplyr"       "ggplot2"     "httr"        "jsonlite"
#  [6] "readr"       "viridis"     "viridisLite" "repr"        "stats"
# [11] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [16] "base"

# %%
url <- "http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2023-09-03/data/listings.csv.gz"
The_Netherlands <- read_csv(gzcon(url(description = url, open = "r")))
# Out:
# Rows: 8386 Columns: 75
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (25): listing_url, source, name, description, neighborhood_overview, pi...
# dbl  (37): id, scrape_id, host_id, host_listings_count, host_total_listings_...
# lgl   (8): host_is_superhost, host_has_profile_pic, host_identity_verified, ...
# date  (5): last_scraped, host_since, calendar_last_scraped, first_review, la...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
The_Netherlands$price <- as.numeric(str_remove_all(The_Netherlands$price, "[$,]"))

# %%
select_data <- The_Netherlands %>% select(price, bedrooms, bathrooms_text)
select_data
# Out:
#      price bedrooms bathrooms_text
# 1     61   NA       1 shared bath
# 2    327    1       2 baths
# 3    109   NA       1.5 baths
# 4    290    3       2.5 baths
# 5    150   NA       1 private bath
# 6     75   NA       1 shared bath
# 7    159   NA       1 bath
# 8    221    1       1 private bath
# 9     69   NA       1.5 shared baths
# 10   146   NA       1 private bath
# 11   155   NA       1.5 baths
# 12    79   NA       1 shared bath
# 13    57   NA       1 shared bath
# 14   240    2       1.5 baths
# 15   269    2       1.5 baths
# 16   329    2       1 bath
# 17   450    2       1.5 baths
# 18   150   NA       1 private bath
# 19   131    1       1 bath
# 20   129    1       1.5 baths
# 21   149    2       1.5 baths
# 22   120    1       1.5 baths
# 23   116    1       1.5 baths
# 24   140   NA       1 bath
# 25   187    1       1.5 baths
# 26    80   NA       1 shared bath
# 27   145    1       1 bath
# 28   300    4       2.5 baths
# 29   200    1       1.5 baths
# 30   260    3       1 bath
# ⋮    ⋮     ⋮        ⋮
# 8357  300   1       1 bath
# 8358  280   1       1.5 baths
# 8359 1449   2       3.5 baths
# 8360  250   1       1 bath
# 8361  250   1       1 bath
# 8362  375   2       1 bath
# 8363  150   1       1 bath
# 8364  256   2       1.5 baths
# 8365  450   2       2 baths
# 8366 1934   4       3 baths
# 8367  180  NA       1 bath
# 8368  150   1       1 bath
# 8369  406   1       1.5 baths
# 8370  176   1       1.5 baths
# 8371  160  NA       1 bath
# 8372  339   1       1 bath
# 8373  700   4       3 baths
# 8374  340   1       1 bath
# 8375  175   2       1 bath
# 8376  269   1       1 bath
# 8377  300   2       1.5 baths
# 8378  310   1       1 bath
# 8379  210   1       1 bath
# 8380  236   2       1.5 baths
# 8381  250   2       1 bath
# 8382  250   1       1 bath
# 8383  337   3       1 bath
# 8384  135   1       1.5 baths
# 8385  160   1       1 shared bath
# 8386  211   2       1 bath

# %%
api_key <- "58c8eb71a98bc0e70380918c4ec1041c"
response <- GET(paste0("http://data.fixer.io/api/latest?access_key=", api_key, "&symbols=EUR,NZD"))
data <- fromJSON(content(response, as = "text"))
exchange_rate_eur_to_nzd <- data$rates$NZD / data$rates$EUR
The_Netherlands$price_nzd <- The_Netherlands$price * exchange_rate_eur_to_nzd
The_Netherlands_nzd <- The_Netherlands %>% mutate(price_nzd = price * exchange_rate_eur_to_nzd) %>% select(price_nzd, bathrooms_text, bedrooms)
The_Netherlands_nzd
# Out:
#      price_nzd bathrooms_text   bedrooms
# 1    109.2329  1 shared bath    NA
# 2    585.5599  2 baths           1
# 3    195.1866  1.5 baths        NA
# 4    519.3039  2.5 baths         3
# 5    268.6054  1 private bath   NA
# 6    134.3027  1 shared bath    NA
# 7    284.7218  1 bath           NA
# 8    395.7454  1 private bath    1
# 9    123.5585  1.5 shared baths NA
# 10   261.4426  1 private bath   NA
# 11   277.5590  1.5 baths        NA
# 12   141.4655  1 shared bath    NA
# 13   102.0701  1 shared bath    NA
# 14   429.7687  1.5 baths         2
# 15   481.6991  1.5 baths         2
# 16   589.1413  1 bath            2
# 17   805.8163  1.5 baths         2
# 18   268.6054  1 private bath   NA
# 19   234.5821  1 bath            1
# 20   231.0007  1.5 baths         1
# 21   266.8147  1.5 baths         2
# 22   214.8844  1.5 baths         1
# 23   207.7215  1.5 baths         1
# 24   250.6984  1 bath           NA
# 25   334.8615  1.5 baths         1
# 26   143.2562  1 shared bath    NA
# 27   259.6519  1 bath            1
# 28   537.2109  2.5 baths         4
# 29   358.1406  1.5 baths         1
# 30   465.5828  1 bath            3
# ⋮    ⋮         ⋮                ⋮
# 8357  537.2109 1 bath            1
# 8358  501.3968 1.5 baths         1
# 8359 2594.7286 3.5 baths         2
# 8360  447.6757 1 bath            1
# 8361  447.6757 1 bath            1
# 8362  671.5136 1 bath            2
# 8363  268.6054 1 bath            1
# 8364  458.4200 1.5 baths         2
# 8365  805.8163 2 baths           2
# 8366 3463.2196 3 baths           4
# 8367  322.3265 1 bath           NA
# 8368  268.6054 1 bath            1
# 8369  727.0254 1.5 baths         1
# 8370  315.1637 1.5 baths         1
# 8371  286.5125 1 bath           NA
# 8372  607.0483 1 bath            1
# 8373 1253.4921 3 baths           4
# 8374  608.8390 1 bath            1
# 8375  313.3730 1 bath            2
# 8376  481.6991 1 bath            1
# 8377  537.2109 1.5 baths         2
# 8378  555.1179 1 bath            1
# 8379  376.0476 1 bath            1
# 8380  422.6059 1.5 baths         2
# 8381  447.6757 1 bath            2
# 8382  447.6757 1 bath            1
# 8383  603.4669 1 bath            3
# 8384  241.7449 1.5 baths         1
# 8385  286.5125 1 shared bath     1
# 8386  377.8383 1 bath            2

# %%
average_price <- aggregate(price_nzd ~ bathrooms_text + bedrooms, data=The_Netherlands_nzd, FUN=mean)

ggplot(average_price, aes(x=bathrooms_text, y=bedrooms)) +
  geom_tile(aes(fill=price_nzd), color='white') +
  scale_fill_viridis(name="Price", direction=-1) + 
  theme_minimal() +  
  labs(title="Average Price Heatmap", x="Bathroom Type", y="Room Count") +
  theme(axis.text.x = element_text(angle=45, hjust=1))
# Out:
# plot without title

# %%
p_hist <- ggplot(The_Netherlands, aes(x = price)) +
  geom_histogram(aes(fill = as.factor(beds)), bins = 30, alpha = 0.7) +
  labs(
    title = "Relationship between beds and price in the Netherlands in NZD",
    x = "Price",
    y = "Count",
    fill = "Beds"
  ) +
  theme_light(base_size = 9.5) +
  theme(
    axis.title = element_text(face = "bold"),
    plot.title = element_text(face = "bold", size = rel(1.5), hjust = 0.5),
    legend.position = "bottom",
    legend.title = element_text(face = "bold")
  ) +
  scale_x_continuous(breaks = seq(0, 1500, 250), limits = c(0, 1500)) +
  scale_fill_brewer(palette = "Set3")

print(p_hist)
# Out:
# Warning message:
# “Removed 19 rows containing non-finite values (`stat_bin()`).”
# Warning message in RColorBrewer::brewer.pal(n, pal):
# “n too large, allowed maximum for palette Set3 is 12
# Returning the palette you asked for with that many colors
# ”
# Warning message:
# “Removed 44 rows containing missing values (`geom_bar()`).”
# plot without title

# %%
#Make a boxplot to see the relationship between room types and prices
p <- ggplot(The_Netherlands_nzd, aes(x = bathrooms_text, y = price_nzd)) +
  geom_boxplot(aes(fill = bathrooms_text), outlier.shape = NA) +
  labs(
    title = "Boxplot of Prices by Room Type in The Netherlands in NZD",
    x = "Room Type",
    y = "Price in NZD"
  ) +
  theme_light(base_size = 9.5) +
  theme(
    axis.text.x = element_text(angle = 45, vjust = 0.5, hjust = 0.5),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(face = "bold", size = rel(1.5), hjust = 0.5),
    legend.position = "bottom",
    legend.title = element_text(face = "bold")
  ) +
  scale_y_continuous(breaks = seq(0, 2000, 500), limits = c(0, 2000)) +
  scale_fill_brewer(palette = "Set3")

print(p)
# Out:
# Warning message:
# “Removed 36 rows containing non-finite values (`stat_boxplot()`).”
# Warning message in RColorBrewer::brewer.pal(n, pal):
# “n too large, allowed maximum for palette Set3 is 12
# Returning the palette you asked for with that many colors
# ”
# plot without title

# %%
p <- ggplot(The_Netherlands_nzd, aes(x = price_nzd)) +
  geom_histogram(binwidth = 100, fill = "#74c476", color = "#238b45", boundary = 0, closed = "left") + 
  labs(
    title = "Distribution of Prices of Airbnb in The Netherlands in NZD",
    x = "Price in NZD",
    y = "Count"
  ) +
  theme_minimal(base_size = 11) +
  theme(
    axis.title = element_text(face = "bold"),
    plot.title = element_text(face = "bold", size = rel(1.5), hjust = 0.5),
    panel.grid.major = element_line(linetype = "dashed", color = "gray85"), 
    panel.background = element_rect(fill = "white"), 
    axis.line = element_line(color = "black") 
  ) +
  scale_x_continuous(breaks = seq(0, 2000, 250), limits = c(0, 2000)) 

print(p)
# Out:
# Warning message:
# “Removed 36 rows containing non-finite values (`stat_bin()`).”
# plot without title
