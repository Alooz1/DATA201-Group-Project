# %%
### Scraping Tokyo Air BNB Data

# %%
# Loading all necessary libraries

library(tidyverse) # loading this library so it allows us to tidy up and graph our data findings
library(magrittr) # loading this library so it allows us to use the pipe operator.
library(purrr) # loading this library so it allows us to create and work with functions
library(glue) # loading this library so it allows us to concatenate variable when it is specified.
library(stringr) # loading this library so it allows us to utilise string manipulations.
library(rvest) # loading this library so it allows us to use functions for web scraping.
library(jsonlite) # loading this library so it allows us to use functions when dealing with files in a JSON format.
library(ggplot2) # loading this library so it allows us to plot graphs
library(httr) #  loading this library so it allows us to access and interact with APIS
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
#
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding
#
#
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %%
# Reading in the CSV that contains all the data about Air BNBs in tokyo
japan_airbnb <- read_csv("http://data.insideairbnb.com/japan/kant%C5%8D/tokyo/2023-09-24/data/listings.csv.gz")
# Out:
# Rows: 12234 Columns: 75
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (25): listing_url, source, name, description, neighborhood_overview, pi...
# dbl  (37): id, scrape_id, host_id, host_listings_count, host_total_listings_...
# lgl   (8): host_is_superhost, host_has_profile_pic, host_identity_verified, ...
# date  (5): last_scraped, host_since, calendar_last_scraped, first_review, la...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# looking into the CSV and viewing the variable names
glimpse(japan_airbnb)
# Out:
# Rows: 12,234
# Columns: 75
# $ id                                           <dbl> 197677, 5240174, 5262640,…
# $ listing_url                                  <chr> "https://www.airbnb.com/r…
# $ scrape_id                                    <dbl> 2.023092e+13, 2.023092e+1…
# $ last_scraped                                 <date> 2023-09-24, 2023-09-24, …
# $ source                                       <chr> "city scrape", "previous …
# $ name                                         <chr> "Rental unit in Sumida · …
# $ description                                  <chr> "<b>The space</b><br />We…
# $ neighborhood_overview                        <chr> NA, NA, "No smoking in th…
# $ picture_url                                  <chr> "https://a0.muscache.com/…
# $ host_id                                      <dbl> 964081, 24477517, 1773656…
# $ host_url                                     <chr> "https://www.airbnb.com/u…
# $ host_name                                    <chr> "Yoshimi & Marek", "Naoko…
# $ host_since                                   <date> 2011-08-13, 2014-12-04, …
# $ host_location                                <chr> "Tokyo, Japan", "Tokyo, J…
# $ host_about                                   <chr> "Would love to travel all…
# $ host_response_time                           <chr> "within a day", "N/A", "w…
# $ host_response_rate                           <chr> "100%", "N/A", "100%", "1…
# $ host_acceptance_rate                         <chr> "94%", "N/A", "100%", "10…
# $ host_is_superhost                            <lgl> TRUE, FALSE, TRUE, TRUE, …
# $ host_thumbnail_url                           <chr> "https://a0.muscache.com/…
# $ host_picture_url                             <chr> "https://a0.muscache.com/…
# $ host_neighbourhood                           <chr> "Sumida District", "Shibu…
# $ host_listings_count                          <dbl> 1, 4, 9, 1, 5, 9, 1, 6, 1…
# $ host_total_listings_count                    <dbl> 2, 4, 16, 6, 18, 16, 4, 9…
# $ host_verifications                           <chr> "['email', 'phone']", "['…
# $ host_has_profile_pic                         <lgl> TRUE, TRUE, TRUE, TRUE, T…
# $ host_identity_verified                       <lgl> TRUE, TRUE, TRUE, TRUE, T…
# $ neighbourhood                                <chr> NA, NA, "Nakano-ku, Tōkyō…
# $ neighbourhood_cleansed                       <chr> "Sumida Ku", "Shibuya Ku"…
# $ neighbourhood_group_cleansed                 <lgl> NA, NA, NA, NA, NA, NA, N…
# $ latitude                                     <dbl> 35.71707, 35.66339, 35.73…
# $ longitude                                    <dbl> 139.8261, 139.6874, 139.6…
# $ property_type                                <chr> "Entire rental unit", "En…
# $ room_type                                    <chr> "Entire home/apt", "Entir…
# $ accommodates                                 <dbl> 2, 4, 2, 1, 6, 2, 2, 5, 2…
# $ bathrooms                                    <lgl> NA, NA, NA, NA, NA, NA, N…
# $ bathrooms_text                               <chr> "1 bath", "1 bath", "1 ba…
# $ bedrooms                                     <dbl> 1, NA, 1, NA, 2, 1, NA, 1…
# $ beds                                         <dbl> 2, 1, 1, 1, 4, 1, 2, 4, 2…
# $ amenities                                    <chr> "[\"Microwave\", \"Hanger…
# $ price                                        <chr> "$12,000.00", "$9,264.00"…
# $ minimum_nights                               <dbl> 3, 2, 3, 3, 3, 3, 30, 2, …
# $ maximum_nights                               <dbl> 1125, 180, 1125, 14, 1125…
# $ minimum_minimum_nights                       <dbl> 3, 2, 3, 3, 1, 3, 30, 2, …
# $ maximum_minimum_nights                       <dbl> 3, 2, 3, 3, 5, 3, 30, 2, …
# $ minimum_maximum_nights                       <dbl> 1125, 1125, 1125, 14, 365…
# $ maximum_maximum_nights                       <dbl> 1125, 1125, 1125, 14, 112…
# $ minimum_nights_avg_ntm                       <dbl> 3.0, 2.0, 3.0, 3.0, 3.7, …
# $ maximum_nights_avg_ntm                       <dbl> 1125.0, 1125.0, 1125.0, 1…
# $ calendar_updated                             <lgl> NA, NA, NA, NA, NA, NA, N…
# $ has_availability                             <lgl> TRUE, TRUE, TRUE, TRUE, T…
# $ availability_30                              <dbl> 0, 0, 30, 0, 3, 17, 13, 0…
# $ availability_60                              <dbl> 0, 0, 60, 0, 7, 47, 43, 0…
# $ availability_90                              <dbl> 0, 0, 90, 0, 20, 77, 53, …
# $ availability_365                             <dbl> 39, 0, 90, 116, 166, 77, …
# $ calendar_last_scraped                        <date> 2023-09-24, 2023-09-24, …
# $ number_of_reviews                            <dbl> 174, 195, 61, 248, 194, 1…
# $ number_of_reviews_ltm                        <dbl> 8, 0, 9, 18, 9, 11, 45, 0…
# $ number_of_reviews_l30d                       <dbl> 0, 0, 0, 1, 1, 0, 2, 0, 0…
# $ first_review                                 <date> 2011-09-21, 2015-04-05, …
# $ last_review                                  <date> 2023-08-13, 2021-12-30, …
# $ review_scores_rating                         <dbl> 4.77, 4.52, 4.80, 4.98, 4…
# $ review_scores_accuracy                       <dbl> 4.74, 4.62, 4.90, 4.96, 4…
# $ review_scores_cleanliness                    <dbl> 4.92, 4.54, 4.85, 4.92, 4…
# $ review_scores_checkin                        <dbl> 4.84, 4.77, 4.93, 4.98, 4…
# $ review_scores_communication                  <dbl> 4.83, 4.83, 4.87, 4.98, 4…
# $ review_scores_location                       <dbl> 4.53, 4.29, 4.61, 4.84, 4…
# $ review_scores_value                          <dbl> 4.79, 4.30, 4.77, 4.91, 4…
# $ license                                      <chr> "M130003350", "M130005396…
# $ instant_bookable                             <lgl> FALSE, TRUE, FALSE, FALSE…
# $ calculated_host_listings_count               <dbl> 1, 4, 9, 1, 5, 9, 1, 2, 1…
# $ calculated_host_listings_count_entire_homes  <dbl> 1, 4, 9, 0, 5, 9, 0, 2, 1…
# $ calculated_host_listings_count_private_rooms <dbl> 0, 0, 0, 1, 0, 0, 1, 0, 0…
# $ calculated_host_listings_count_shared_rooms  <dbl> 0, 0, 0, 0, 0, 0, 0, 0, 0…
# $ reviews_per_month                            <dbl> 1.19, 1.89, 0.59, 1.88, 1…

# %%
# cleaining up the price column to remove $ symbols

japan_airbnb$price <- as.numeric(gsub(",", "", gsub("\\$", "", japan_airbnb$price)))

# %%
# wrangling the data and creating a table with the selected variables

japan_airbnb <- (japan_airbnb %>% select(price,bathrooms_text, bedrooms))
japan_airbnb
# Out:
#       price  bathrooms_text   bedrooms
# 1     12000  1 bath            1
# 2      9264  1 bath           NA
# 3      7419  1 bath            1
# 4      8902  1 shared bath    NA
# 5     23740  1 bath            2
# 6      7419  1 bath            1
# 7     24000  1 shared bath    NA
# 8     10000  1 bath            1
# 9      9644  1 bath            1
# 10     5200  1.5 shared baths NA
# 11    11000  1.5 baths        NA
# 12    47904  1 bath            1
# 13     9500  1 bath           NA
# 14     8000  1 shared bath    NA
# 15     8902  1 bath            1
# 16    19400  2 baths           2
# 17    41143  1 bath            1
# 18     8902  1 bath            2
# 19    36429  2.5 baths         2
# 20    16857  1.5 baths         1
# 21    14357  1 bath            1
# 22    10500  1 private bath   NA
# 23     7980  1 shared bath    NA
# 24     7980  1 shared bath    NA
# 25     5243  1 bath            1
# 26     5980  1 shared bath    NA
# 27     5800  1 shared bath    NA
# 28     5980  1 shared bath    NA
# 29     3800  1 shared bath    NA
# 30    15000  1.5 baths         1
# ⋮     ⋮      ⋮                ⋮
# 12205 184615 1.5 baths        2
# 12206  47500 1 bath           2
# 12207  40000 1 bath           1
# 12208  60000 2 baths          1
# 12209  40000 1 bath           1
# 12210   5000 1 bath           1
# 12211  60000 2 baths          1
# 12212  12000 1 bath           1
# 12213  15000 1 bath           1
# 12214  16571 1 bath           2
# 12215  89857 1 bath           2
# 12216  75000 1 bath           1
# 12217  17286 1 bath           1
# 12218  97000 1 bath           1
# 12219   7500 Half-bath        1
# 12220  80000 1 bath           1
# 12221   8714 1 bath           1
# 12222  15000 1 bath           1
# 12223  10500 1.5 baths        1
# 12224   8071 1 bath           1
# 12225   8857 1 bath           1
# 12226  42857 1 bath           3
# 12227   8000 Half-bath        1
# 12228  48000 1 bath           2
# 12229   8000 Half-bath        1
# 12230  15857 1 bath           1
# 12231   6500 1 private bath   1
# 12232  14549 1.5 baths        3
# 12233  18500 1.5 baths        1
# 12234  15349 1.5 baths        3

# %%
# API key for fixer.io a live exchange rate site so we can convert the price column from JPY to NZD

api_key <- "58c8eb71a98bc0e70380918c4ec1041c"

# %%
# making a GET request to get the exchange rate data for JPY to NZD
response <- GET(paste0("http://data.fixer.io/api/latest?access_key=", api_key, "&symbols=JPY,NZD"))

# %%
# parsing the JSON data to create a data structure and makes it easier to work with
data <- fromJSON(content(response, as = "text"))

# %%
# calculating the exchange of JPY to NZD
exchange_rate_jpy_to_nzd <- data$rates$NZD / data$rates$JPY

# %%
# swapping the previous price column with the new price in NZD
japan_airbnb$price_nzd <- japan_airbnb$price * exchange_rate_jpy_to_nzd

# %%
# creating the same table with the new price in NZD
japan_airbnb_nzd <- japan_airbnb %>%
  mutate(price_nzd = price * exchange_rate_jpy_to_nzd) %>%
  select(price_nzd, bathrooms_text, bedrooms)

japan_airbnb_nzd
# Out:
#       price_nzd  bathrooms_text   bedrooms
# 1     136.03608  1 bath            1
# 2     105.01985  1 bath           NA
# 3      84.10431  1 bath            1
# 4     100.91610  1 shared bath    NA
# 5     269.12471  1 bath            2
# 6      84.10431  1 bath            1
# 7     272.07216  1 shared bath    NA
# 8     113.36340  1 bath            1
# 9     109.32766  1 bath            1
# 10     58.94897  1.5 shared baths NA
# 11    124.69974  1.5 baths        NA
# 12    543.05604  1 bath            1
# 13    107.69523  1 bath           NA
# 14     90.69072  1 shared bath    NA
# 15    100.91610  1 bath            1
# 16    219.92500  2 baths           2
# 17    466.41104  1 bath            1
# 18    100.91610  1 bath            2
# 19    412.97153  2.5 baths         2
# 20    191.09669  1.5 baths         1
# 21    162.75584  1 bath            1
# 22    119.03157  1 private bath   NA
# 23     90.46399  1 shared bath    NA
# 24     90.46399  1 shared bath    NA
# 25     59.43643  1 bath            1
# 26     67.79131  1 shared bath    NA
# 27     65.75077  1 shared bath    NA
# 28     67.79131  1 shared bath    NA
# 29     43.07809  1 shared bath    NA
# 30    170.04510  1.5 baths         1
# ⋮     ⋮          ⋮                ⋮
# 12205 2092.85843 1.5 baths        2
# 12206  538.47616 1 bath           2
# 12207  453.45360 1 bath           1
# 12208  680.18041 2 baths          1
# 12209  453.45360 1 bath           1
# 12210   56.68170 1 bath           1
# 12211  680.18041 2 baths          1
# 12212  136.03608 1 bath           1
# 12213  170.04510 1 bath           1
# 12214  187.85449 1 bath           2
# 12215 1018.64951 1 bath           2
# 12216  850.22551 1 bath           1
# 12217  195.95998 1 bath           1
# 12218 1099.62499 1 bath           1
# 12219   85.02255 Half-bath        1
# 12220  906.90721 1 bath           1
# 12221   98.78487 1 bath           1
# 12222  170.04510 1 bath           1
# 12223  119.03157 1.5 baths        1
# 12224   91.49560 1 bath           1
# 12225  100.40596 1 bath           1
# 12226  485.84153 1 bath           3
# 12227   90.69072 Half-bath        1
# 12228  544.14433 1 bath           2
# 12229   90.69072 Half-bath        1
# 12230  179.76035 1 bath           1
# 12231   73.68621 1 private bath   1
# 12232  164.93241 1.5 baths        3
# 12233  209.72229 1.5 baths        1
# 12234  174.00148 1.5 baths        3

# %%
# subsetting the data to the first 100 rows as the data contains 46,000 rows
subset_data <- japan_airbnb[1:100, ]

# %%
# creating a plot for the price distribution in JPY 
p1 <- ggplot(subset_data, aes(x = price)) + 
  geom_histogram(fill = "steelblue", color = "white", bins = 30) + 
  ggtitle("Distribution of Prices For AirBNBS in Tokyo (Japanese Yen)") + 
  xlab("Price (JPY)") + 
  ylab("Number of AirBNBS")

p1
# Out:
# plot without title

# %%
# creating a plot for the price distribution in NZD
p2 <- ggplot(japan_airbnb_nzd, aes(x = price_nzd)) + 
  geom_histogram(fill = "steelblue", color = "white", bins = 30) + 
  ggtitle("Price Distribution Of AirBNBS in Tokyo ($NZD)") + 
  xlab("Price (NZD)") + 
  ylab("Number of AirBNBs") +
  xlim(100, 1000)

p2
# Out:
# Warning message:
# “Removed 3617 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# plot without title

# %%
# creating a plot for the distribution of bedrooms
p3 <- ggplot(subset_data, aes(x = as.factor(bedrooms))) + 
  geom_bar(fill = "steelblue") + 
  ggtitle("Distribution of Bedrooms For AirBNBs in Tokyo") + 
  xlab("Number of Bedrooms") + 
  ylab("Number Of AirBNBs")
p3
# Out:
# plot without title

# %%
# creating a plot for the distribution of bathrooms

p4 <- ggplot(subset_data, aes(x = bathrooms_text)) + 
  geom_bar(fill = "steelblue") + 
  ggtitle("Distribution of Bathroom Types For AirBNBs in Tokyo )") + 
  xlab("Bathroom Types") + 
  ylab("Number Of AirBNBs") + 
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
p4
# Out:
# plot without title

# %%
# plotting the price against amount of bedrooms
p5 <- ggplot(subset_data, aes(x = bedrooms, y = price)) + 
  geom_point(aes(color = bedrooms)) + 
  ggtitle("Price vs. Number of Bedrooms For AirBNBS in Tokyo") + 
  xlab("Number of Bedrooms") + 
  ylab("Price (JPY)")
p5
# Out:
# Warning message:
# “Removed 34 rows containing missing values (`geom_point()`).”
# plot without title

# %%
# plotting the price against amount of bathrooms

p6 <- ggplot(subset_data, aes(x = bathrooms_text, y = price)) + 
  geom_boxplot(aes(fill = bathrooms_text)) + 
  ggtitle("Price vs. Bathroom Types For AirBNBS in Tokyo") + 
  xlab("Bathroom Types") + 
  ylab("Price (JPY)") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
p6
# Out:
# plot without title
